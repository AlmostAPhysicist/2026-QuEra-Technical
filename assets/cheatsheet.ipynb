# %% [markdown]
# # Squin gates of interest
#
# given immutable lists `q: IList[Qubit, Literal[7]]` of qubits, and `p: float` noise rate

# %% [markdown]
# ### Depolarizing noise channels

# %%
from bloqade import squin
from kirin.dialects.ilist import IList


# a squin kernel
@squin.kernel
def good_to_know(p: float = 0):
    q = squin.qalloc(3)  # allocate qubits

    # Single qubit noise with parameter p; broadcast applies channel in parallel to all qubits in list
    squin.broadcast.depolarize(p, IList([q[0], q[1]]))

    # Two-qubit noise
    squin.depolarize2(p, q[0], q[1])

    return q

# %% [markdown]
# ### Measure and reset

# %%
# measure
squin.broadcast.measure(q)

# reset
squin.broadcast.reset(q)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 # example usage
# ----> 2 q = good_to_know(p=0.01)
#       4 # measure
#       5 squin.broadcast.measure(q)
#
# File c:\Users\aryan\.conda\envs\iquhack\Lib\site-packages\kirin\ir\method.py:126, in Method.__call__(self, *args, **kwargs)
#     124 # NOTE: multi-return values will be wrapped in a tuple for Python
#     125 interp = Interpreter(self.dialects)
# --> 126 _, ret = interp.run(self, *args, **kwargs)
#     127 return ret
#
# File c:\Users\aryan\.conda\envs\iquhack\Lib\site-packages\kirin\interp\concrete.py:24, in Interpreter.run(self, method, *args, **kwargs)
#      23 def run(self, method: ir.Method, *args, **kwargs):
# ---> 24     return self.call(method, method, *args, **kwargs)
#
# File c:\Users\aryan\.conda\envs\iquhack\Lib\site-packages\kirin\interp\abc.py:106, in InterpreterABC.call(self, node, *args, **kwargs)
#      87 """Call a given callable node with the given arguments.
#      88
#      89 This method is used to call a node that has a callable trait and a
#    (...)    103     StackOverflowError: if the maximum depth of the interpreter stack is reached
#     104 """
#     105 if isinstance(node, ir.Method):
# --> 106     return self.__call_method(node, *args, **kwargs)
#     108 with self.new_frame(node) as frame:
#     109     return frame, self.frame_call(frame, node, *args, **kwargs)
#
# File c:\Users\aryan\.conda\envs\iquhack\Lib\site-packages\kirin\interp\abc.py:131, in InterpreterABC.__call_method(self, node, *args, **kwargs)
#     125     raise InterpreterError(
#     126         f"Method {node} called with {len(args) + len(kwargs)} "
#     127         f"arguments, expected {node.nargs}"
#     128     )
#     130 with self.eval_context():
# --> 131     return self.call(node.code, *args, **kwargs)
#
# File c:\Users\aryan\.conda\envs\iquhack\Lib\site-packages\kirin\interp\abc.py:109, in InterpreterABC.call(self, node, *args, **kwargs)
#     106     return self.__call_method(node, *args, **kwargs)
#     108 with self.new_frame(node) as frame:
# --> 109     return frame, self.frame_call(frame, node, *args, **kwargs)
#
# File c:\Users\aryan\.conda\envs\iquhack\Lib\site-packages\kirin\interp\abc.py:184, in InterpreterABC.frame_call(self, frame, node, *args, **kwargs)
#     181 if self.state.depth >= self.max_depth:
#     182     return self.recursion_limit_reached()
# --> 184 ret = self.frame_call_region(frame, node, region, *args)
#     185 if isinstance(ret, ReturnValue):
#     186     return ret.value
#
# File c:\Users\aryan\.conda\envs\iquhack\Lib\site-packages\kirin\interp\abc.py:242, in InterpreterABC.frame_call_region(self, frame, node, region, *args)
#     237     raise InterpreterError(
#     238         f"Interpreter {self.__class__.__name__} does not "
#     239         f"support {node} using {region_trait} convention"
#     240     )
#     241 region_trait.set_region_input(frame, region, *args)
# --> 242 return how(self, frame, region)
#
# File c:\Users\aryan\.conda\envs\iquhack\Lib\site-packages\kirin\interp\table.py:98, in BoundedDef.__call__(self, interpreter, frame, node)
#      92 def __call__(
#      93     self,
#      94     interpreter: InterpreterType,
#      95     frame: FrameType,
#      96     node: NodeType,
#      97 ) -> Ret:
# ---> 98     return self.method(self.parent, interpreter, frame, node)
#
# File c:\Users\aryan\.conda\envs\iquhack\Lib\site-packages\kirin\dialects\ssacfg.py:22, in Concrete.ssacfg(self, interp_, frame, node)
#      20 for stmt in block.stmts:
#      21     frame.current_stmt = stmt
# ---> 22     stmt_results = interp_.frame_eval(frame, stmt)
#      23     match stmt_results:
#      24         case tuple():
#
# File c:\Users\aryan\.conda\envs\iquhack\Lib\site-packages\kirin\interp\abc.py:286, in InterpreterABC.frame_eval(self, frame, node)
#     284 method = self.lookup_registry(frame, node)
#     285 if method is not None:
# --> 286     results = method(self, frame, node)
#     287     if self.debug and not isinstance(results, (tuple, SpecialValue)):
#     288         raise InterpreterError(
#     289             f"method must return tuple or SpecialResult, got {results}"
#     290         )
#
# File c:\Users\aryan\.conda\envs\iquhack\Lib\site-packages\kirin\interp\table.py:98, in BoundedDef.__call__(self, interpreter, frame, node)
#      92 def __call__(
#      93     self,
#      94     interpreter: InterpreterType,
#      95     frame: FrameType,
#      96     node: NodeType,
#      97 ) -> Ret:
# ---> 98     return self.method(self.parent, interpreter, frame, node)
#
# File c:\Users\aryan\.conda\envs\iquhack\Lib\site-packages\kirin\dialects\func\interp.py:24, in Interpreter.invoke(self, interp, frame, stmt)
#      22 @impl(Invoke)
#      23 def invoke(self, interp: concrete.Interpreter, frame: Frame, stmt: Invoke):
# ---> 24     _, ret = interp.call(
#      25         stmt.callee.code,
#      26         stmt.callee,
#      27         *frame.get_values(stmt.inputs),
#      28     )
#      29     return (ret,)
#
# File c:\Users\aryan\.conda\envs\iquhack\Lib\site-packages\kirin\interp\abc.py:109, in InterpreterABC.call(self, node, *args, **kwargs)
#     106     return self.__call_method(node, *args, **kwargs)
#     108 with self.new_frame(node) as frame:
# --> 109     return frame, self.frame_call(frame, node, *args, **kwargs)
#
# File c:\Users\aryan\.conda\envs\iquhack\Lib\site-packages\kirin\interp\abc.py:184, in InterpreterABC.frame_call(self, frame, node, *args, **kwargs)
#     181 if self.state.depth >= self.max_depth:
#     182     return self.recursion_limit_reached()
# --> 184 ret = self.frame_call_region(frame, node, region, *args)
#     185 if isinstance(ret, ReturnValue):
#     186     return ret.value
#
# File c:\Users\aryan\.conda\envs\iquhack\Lib\site-packages\kirin\interp\abc.py:242, in InterpreterABC.frame_call_region(self, frame, node, region, *args)
#     237     raise InterpreterError(
#     238         f"Interpreter {self.__class__.__name__} does not "
#     239         f"support {node} using {region_trait} convention"
#     240     )
#     241 region_trait.set_region_input(frame, region, *args)
# --> 242 return how(self, frame, region)
#
# File c:\Users\aryan\.conda\envs\iquhack\Lib\site-packages\kirin\interp\table.py:98, in BoundedDef.__call__(self, interpreter, frame, node)
#      92 def __call__(
#      93     self,
#      94     interpreter: InterpreterType,
#      95     frame: FrameType,
#      96     node: NodeType,
#      97 ) -> Ret:
# ---> 98     return self.method(self.parent, interpreter, frame, node)
#
# File c:\Users\aryan\.conda\envs\iquhack\Lib\site-packages\kirin\dialects\ssacfg.py:22, in Concrete.ssacfg(self, interp_, frame, node)
#      20 for stmt in block.stmts:
#      21     frame.current_stmt = stmt
# ---> 22     stmt_results = interp_.frame_eval(frame, stmt)
#      23     match stmt_results:
#      24         case tuple():
#
# File c:\Users\aryan\.conda\envs\iquhack\Lib\site-packages\kirin\interp\abc.py:286, in InterpreterABC.frame_eval(self, frame, node)
#     284 method = self.lookup_registry(frame, node)
#     285 if method is not None:
# --> 286     results = method(self, frame, node)
#     287     if self.debug and not isinstance(results, (tuple, SpecialValue)):
#     288         raise InterpreterError(
#     289             f"method must return tuple or SpecialResult, got {results}"
#     290         )
#
# File c:\Users\aryan\.conda\envs\iquhack\Lib\site-packages\kirin\interp\table.py:98, in BoundedDef.__call__(self, interpreter, frame, node)
#      92 def __call__(
#      93     self,
#      94     interpreter: InterpreterType,
#      95     frame: FrameType,
#      96     node: NodeType,
#      97 ) -> Ret:
# ---> 98     return self.method(self.parent, interpreter, frame, node)
#
# File c:\Users\aryan\.conda\envs\iquhack\Lib\site-packages\kirin\dialects\ilist\interp.py:43, in IListInterpreter.map(self, interp, frame, stmt)
#      40 ret = []
#      41 for elem in coll.data:
#      42     # NOTE: assume fn has been type checked
# ---> 43     _, item = interp.call(fn.code, fn, elem)
#      44     ret.append(item)
#      45 return (IList(ret, elem=fn.return_type),)
#
# File c:\Users\aryan\.conda\envs\iquhack\Lib\site-packages\kirin\interp\abc.py:109, in InterpreterABC.call(self, node, *args, **kwargs)
#     106     return self.__call_method(node, *args, **kwargs)
#     108 with self.new_frame(node) as frame:
# --> 109     return frame, self.frame_call(frame, node, *args, **kwargs)
#
# File c:\Users\aryan\.conda\envs\iquhack\Lib\site-packages\kirin\interp\abc.py:184, in InterpreterABC.frame_call(self, frame, node, *args, **kwargs)
#     181 if self.state.depth >= self.max_depth:
#     182     return self.recursion_limit_reached()
# --> 184 ret = self.frame_call_region(frame, node, region, *args)
#     185 if isinstance(ret, ReturnValue):
#     186     return ret.value
#
# File c:\Users\aryan\.conda\envs\iquhack\Lib\site-packages\kirin\interp\abc.py:242, in InterpreterABC.frame_call_region(self, frame, node, region, *args)
#     237     raise InterpreterError(
#     238         f"Interpreter {self.__class__.__name__} does not "
#     239         f"support {node} using {region_trait} convention"
#     240     )
#     241 region_trait.set_region_input(frame, region, *args)
# --> 242 return how(self, frame, region)
#
# File c:\Users\aryan\.conda\envs\iquhack\Lib\site-packages\kirin\interp\table.py:98, in BoundedDef.__call__(self, interpreter, frame, node)
#      92 def __call__(
#      93     self,
#      94     interpreter: InterpreterType,
#      95     frame: FrameType,
#      96     node: NodeType,
#      97 ) -> Ret:
# ---> 98     return self.method(self.parent, interpreter, frame, node)
#
# File c:\Users\aryan\.conda\envs\iquhack\Lib\site-packages\kirin\dialects\ssacfg.py:22, in Concrete.ssacfg(self, interp_, frame, node)
#      20 for stmt in block.stmts:
#      21     frame.current_stmt = stmt
# ---> 22     stmt_results = interp_.frame_eval(frame, stmt)
#      23     match stmt_results:
#      24         case tuple():
#
# File c:\Users\aryan\.conda\envs\iquhack\Lib\site-packages\kirin\interp\abc.py:301, in InterpreterABC.frame_eval(self, frame, node)
#     294     dialects = ", ".join(d.name for d in self.dialects)
#     295     raise InterpreterError(
#     296         f"Interpreter {self.__class__.__name__} does not "
#     297         f"support {node} using {name} dialect. "
#     298         f"Expected {dialects}"
#     299     )
# --> 301 return self.eval_fallback(frame, node)
#
# File c:\Users\aryan\.conda\envs\iquhack\Lib\site-packages\kirin\interp\abc.py:320, in InterpreterABC.eval_fallback(self, frame, node)
#     303 def eval_fallback(
#     304     self, frame: FrameType, node: ir.Statement
#     305 ) -> StatementResult[ValueType]:
#     306     """The fallback implementation of statements.
#     307
#     308     This is called when no implementation is found for the statement.
#    (...)    318         Overload this method to provide a fallback implementation for statements.
#     319     """
# --> 320     raise NotImplementedError(
#     321         f"Missing implementation for {type(node).__name__} at {node.source}"
#     322     )
#
# NotImplementedError: Missing implementation for New at File "c:\Users\aryan\.conda\envs\iquhack\Lib\site-packages\bloqade\qubit\stdlib\_new.py", line 32, col 15

# %% [markdown]
# note that to implement resets and measurements on single qubits, just drop `.broadcast` and apply to single-qubit registers.

# %% [markdown]
# # From Bloqade Squin kernels to stabilizer samplers
# ### Convert circuit to Stim/Tsim, visualize, run sampler

# %%
import bloqade.stim
import bloqade.tsim


@squin.kernel
def main():
    good_to_know(p=0.01)


# plotting circuit diagram (plotting is nicer on Tsim)
tsim_circ = bloqade.tsim.Circuit(main)
tsim_circ.diagram(height=400)

# sampling using Stim (Clifford-only sampling is faster on Stim)
stim_circ = bloqade.stim.Circuit(main)
sampler = stim_circ.compile_sampler()
samples = sampler.sample(shots=100)
# Out:
# my_kernel is not defined

# %% [markdown]
# # On noise
# ### Using and adjusting heuristic noise model

# %%
from bloqade.cirq_utils import noise
from bloqade.cirq_utils.emit import emit_circuit
from bloqade.cirq_utils import load_circuit


# applying noise model to circuit according to different architectures; must use Cirq circuit
@squin.kernel
def main():
    my_kernel()


cirq_main = emit_circuit(main)  # emit to Cirq
noise_model = (
    noise.GeminiOneZoneNoiseModel()
)  # define noise model; here OneZone default
main_noisy = noise.transform_circuit(
    cirq_main, model=noise_model
)  # annotate circuit w noise
squin_main = load_circuit(main_noisy)  # back to Squin
noisy_stim = bloqade.stim.Circuit(squin_main)  # now to Stim


# Example 1: defining new noise model on top of OneZone architecture, scaling all noise parameters by a constant factor
noise_scale = 1
noise_model_1 = noise.GeminiOneZoneNoiseModel(scaling_factor=noise_scale)

# Example 2: changing just some of the channels: no local phase-z errors
noise_model_2 = noise.GeminiOneZoneNoiseModel(local_pz=0.0)
